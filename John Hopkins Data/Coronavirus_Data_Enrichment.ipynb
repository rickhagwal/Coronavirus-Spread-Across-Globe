# %%
# !ls '/content/drive/My Drive/Colab Notebooks/twitter.properties'
# Out:
# '/content/drive/My Drive/Colab Notebooks/twitter.properties'

# %%
# !pip install ConfigParser

# %%
import configparser
config = configparser.RawConfigParser()
config.read('/content/drive/My Drive/Colab Notebooks/twitter.properties')
print(config.sections())
# Out:
# ['twitter']

# %%
import pandas as pd
import numpy as np

# %%
corona_confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')

# %%
corona_confirmed_df
# Out:
#     Province/State         Country/Region        Lat  ...  5/25/20  5/26/20  5/27/20
# 0              NaN            Afghanistan  33.000000  ...    11173    11831    12456
# 1              NaN                Albania  41.153300  ...     1004     1029     1050
# 2              NaN                Algeria  28.033900  ...     8503     8697     8857
# 3              NaN                Andorra  42.506300  ...      763      763      763
# 4              NaN                 Angola -11.202700  ...       70       70       71
# ..             ...                    ...        ...  ...      ...      ...      ...
# 261            NaN  Sao Tome and Principe   0.186360  ...      299      441      443
# 262            NaN                  Yemen  15.552727  ...      233      249      256
# 263            NaN                Comoros -11.645500  ...       87       87       87
# 264            NaN             Tajikistan  38.861034  ...     3100     3266     3424
# ...

# %%
corona_death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')

# %%
corona_death_df.head(10)
# Out:
#                  Province/State       Country/Region  ...  5/26/20  5/27/20
# 0                           NaN          Afghanistan  ...      220      227
# 1                           NaN              Albania  ...       33       33
# 2                           NaN              Algeria  ...      617      623
# 3                           NaN              Andorra  ...       51       51
# 4                           NaN               Angola  ...        4        4
# 5                           NaN  Antigua and Barbuda  ...        3        3
# 6                           NaN            Argentina  ...      484      500
# 7                           NaN              Armenia  ...       91       98
# 8  Australian Capital Territory            Australia  ...        3        3
# 9               New South Wales            Australia  ...       48       48
#
# [10 rows x 131 columns]

# %%
corona_recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
corona_recovered_df.head(10)
# Out:
#                  Province/State       Country/Region  ...  5/26/20  5/27/20
# 0                           NaN          Afghanistan  ...     1128     1138
# 1                           NaN              Albania  ...      803      812
# 2                           NaN              Algeria  ...     4918     5129
# 3                           NaN              Andorra  ...      676      676
# 4                           NaN               Angola  ...       18       18
# 5                           NaN  Antigua and Barbuda  ...       19       19
# 6                           NaN            Argentina  ...     4167     4349
# 7                           NaN              Armenia  ...     3220     3255
# 8  Australian Capital Territory            Australia  ...      104      104
# 9               New South Wales            Australia  ...     2663     2670
#
# [10 rows x 131 columns]

# %%
corona_confirmed_df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '5/18/20', '5/19/20', '5/20/20', '5/21/20', '5/22/20', '5/23/20',
#        '5/24/20', '5/25/20', '5/26/20', '5/27/20'],
#       dtype='object', length=131)

# %%
corona_confirmed_df = corona_confirmed_df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long']).rename({'Province/State':'State','Country/Region':'Country','variable':'Date','value':'Confirmed'},axis='columns')
corona_confirmed_df
# Out:
#       State                Country        Lat       Long     Date  Confirmed
# 0       NaN            Afghanistan  33.000000  65.000000  1/22/20          0
# 1       NaN                Albania  41.153300  20.168300  1/22/20          0
# 2       NaN                Algeria  28.033900   1.659600  1/22/20          0
# 3       NaN                Andorra  42.506300   1.521800  1/22/20          0
# 4       NaN                 Angola -11.202700  17.873900  1/22/20          0
# ...     ...                    ...        ...        ...      ...        ...
# 33777   NaN  Sao Tome and Principe   0.186360   6.613081  5/27/20        443
# 33778   NaN                  Yemen  15.552727  48.516388  5/27/20        256
# 33779   NaN                Comoros -11.645500  43.333300  5/27/20         87
# 33780   NaN             Tajikistan  38.861034  71.276093  5/27/20       3424
# 33781   NaN                Lesotho -29.609988  28.233608  5/27/20          2
#
# [33782 rows x 6 columns]

# %%
corona_recovered_df = corona_recovered_df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long']).rename({'variable':'Date','value':'Recovered'},axis='columns')
corona_recovered_df.rename({'Province/State':'State','Country/Region':'Country'},axis='columns',inplace=True)
corona_recovered_df
# Out:
#       State                Country        Lat       Long     Date  Recovered
# 0       NaN            Afghanistan  33.000000  65.000000  1/22/20          0
# 1       NaN                Albania  41.153300  20.168300  1/22/20          0
# 2       NaN                Algeria  28.033900   1.659600  1/22/20          0
# 3       NaN                Andorra  42.506300   1.521800  1/22/20          0
# 4       NaN                 Angola -11.202700  17.873900  1/22/20          0
# ...     ...                    ...        ...        ...      ...        ...
# 32126   NaN  Sao Tome and Principe   0.186360   6.613081  5/27/20         68
# 32127   NaN                  Yemen  15.552727  48.516388  5/27/20         10
# 32128   NaN                Comoros -11.645500  43.333300  5/27/20         24
# 32129   NaN             Tajikistan  38.861034  71.276093  5/27/20       1575
# 32130   NaN                Lesotho -29.609988  28.233608  5/27/20          0
#
# [32131 rows x 6 columns]

# %%
corona_death_df = corona_death_df.melt(id_vars=['Province/State', 'Country/Region', 'Lat', 'Long']).rename({'variable':'Date','value':'Death'},axis='columns')
corona_death_df.rename({'Province/State':'State','Country/Region':'Country'},axis='columns',inplace=True)
corona_death_df.head(10)
# Out:
#                           State              Country  ...     Date  Death
# 0                           NaN          Afghanistan  ...  1/22/20      0
# 1                           NaN              Albania  ...  1/22/20      0
# 2                           NaN              Algeria  ...  1/22/20      0
# 3                           NaN              Andorra  ...  1/22/20      0
# 4                           NaN               Angola  ...  1/22/20      0
# 5                           NaN  Antigua and Barbuda  ...  1/22/20      0
# 6                           NaN            Argentina  ...  1/22/20      0
# 7                           NaN              Armenia  ...  1/22/20      0
# 8  Australian Capital Territory            Australia  ...  1/22/20      0
# 9               New South Wales            Australia  ...  1/22/20      0
#
# [10 rows x 6 columns]

# %%
combined_df = [corona_confirmed_df, corona_death_df, corona_recovered_df]
combined_df
# Out:
# [      State                Country        Lat       Long     Date  Confirmed
#  0       NaN            Afghanistan  33.000000  65.000000  1/22/20          0
#  1       NaN                Albania  41.153300  20.168300  1/22/20          0
#  2       NaN                Algeria  28.033900   1.659600  1/22/20          0
#  3       NaN                Andorra  42.506300   1.521800  1/22/20          0
#  4       NaN                 Angola -11.202700  17.873900  1/22/20          0
#  ...     ...                    ...        ...        ...      ...        ...
#  33777   NaN  Sao Tome and Principe   0.186360   6.613081  5/27/20        443
#  33778   NaN                  Yemen  15.552727  48.516388  5/27/20        256
#  33779   NaN                Comoros -11.645500  43.333300  5/27/20         87
#  33780   NaN             Tajikistan  38.861034  71.276093  5/27/20       3424
#  33781   NaN                Lesotho -29.609988  28.233608  5/27/20          2
#
#  [33782 rows x 6 columns],
# ...

# %%
combined_df = [df.set_index(['State', 'Country', 'Lat', 'Long','Date']) for df in combined_df]
combined_df
# Out:
# [                                                          Confirmed
#  State Country               Lat        Long      Date
#  NaN   Afghanistan            33.000000 65.000000 1/22/20          0
#        Albania                41.153300 20.168300 1/22/20          0
#        Algeria                28.033900 1.659600  1/22/20          0
#        Andorra                42.506300 1.521800  1/22/20          0
#        Angola                -11.202700 17.873900 1/22/20          0
#  ...                                                             ...
#        Sao Tome and Principe  0.186360  6.613081  5/27/20        443
#        Yemen                  15.552727 48.516388 5/27/20        256
#        Comoros               -11.645500 43.333300 5/27/20         87
#        Tajikistan             38.861034 71.276093 5/27/20       3424
#        Lesotho               -29.609988 28.233608 5/27/20          2
#
#  [33782 rows x 1 columns],
# ...

# %%
combined_df = combined_df[0].astype(str).join(combined_df[1:])
combined_df
# Out:
#                                                          Confirmed  ...  Recovered
# State Country               Lat        Long      Date               ...
# NaN   Afghanistan            33.000000 65.000000 1/22/20         0  ...        0.0
#       Albania                41.153300 20.168300 1/22/20         0  ...        0.0
#       Algeria                28.033900 1.659600  1/22/20         0  ...        0.0
#       Andorra                42.506300 1.521800  1/22/20         0  ...        0.0
#       Angola                -11.202700 17.873900 1/22/20         0  ...        0.0
# ...                                                            ...  ...        ...
#       Sao Tome and Principe  0.186360  6.613081  5/27/20       443  ...       68.0
#       Yemen                  15.552727 48.516388 5/27/20       256  ...        NaN
#       Comoros               -11.645500 43.333300 5/27/20        87  ...       24.0
# ...

# %%
combined_df= combined_df.reset_index()

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33782 entries, 0 to 33781
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      10287 non-null  object
#  1   Country    33782 non-null  object
#  2   Lat        33782 non-null  float64
#  3   Long       33782 non-null  float64
#  4   Date       33782 non-null  object
#  5   Confirmed  33782 non-null  object
#  6   Death      33274 non-null  float64
#  7   Recovered  30226 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 2.1+ MB

# %%
combined_df.describe()
# Out:
#                 Lat          Long          Death      Recovered
# count  33782.000000  33782.000000   33274.000000   30226.000000
# mean      21.148043     22.538640     385.764411    2043.650169
# std       24.863491     70.334717    3439.986317   13588.269865
# min      -51.796300   -135.000000       0.000000       0.000000
# 25%        6.877000    -19.020800       0.000000       0.000000
# 50%       23.488100     20.972650       0.000000       4.000000
# 75%       41.153300     78.000000       7.000000     155.000000
# max       71.706900    178.065000  100417.000000  391508.000000

# %%
combined_df.columns
# Out:
# Index(['State', 'Country', 'Lat', 'Long', 'Date', 'Confirmed', 'Death',
#        'Recovered'],
#       dtype='object')

# %%
# Confirmed 'Lat', 'Long',  'Confirmed','Death', 'Recovered' to numeric
combined_df[['Lat', 'Long',  'Confirmed','Death', 'Recovered']] = combined_df[['Lat', 'Long', 'Confirmed','Death', 'Recovered']].apply(pd.to_numeric)

# %%
# COnvert date column to date datatype
combined_df[['Date']] = combined_df[['Date']].apply(pd.to_datetime)

# %%
# for some states like -in us, state column will have both city and state as well. we need to clean that as well
# In some states, COuntry is given

# %%
combined_df
# Out:
#       State                Country        Lat  ...  Confirmed Death  Recovered
# 0       NaN            Afghanistan  33.000000  ...          0   0.0        0.0
# 1       NaN                Albania  41.153300  ...          0   0.0        0.0
# 2       NaN                Algeria  28.033900  ...          0   0.0        0.0
# 3       NaN                Andorra  42.506300  ...          0   0.0        0.0
# 4       NaN                 Angola -11.202700  ...          0   0.0        0.0
# ...     ...                    ...        ...  ...        ...   ...        ...
# 33777   NaN  Sao Tome and Principe   0.186360  ...        443  12.0       68.0
# 33778   NaN                  Yemen  15.552727  ...        256  53.0        NaN
# 33779   NaN                Comoros -11.645500  ...         87   2.0       24.0
# 33780   NaN             Tajikistan  38.861034  ...       3424  47.0        NaN
# 33781   NaN                Lesotho -29.609988  ...          2   0.0        0.0
#
# ...

# %%
combined_df.isnull().any()

# We cans ee taht Death and Recovered columns have nmull values
# Out:
# State         True
# Country      False
# Lat          False
# Long         False
# Date         False
# Confirmed    False
# Death         True
# Recovered     True
# dtype: bool

# %%
combined_df.count()
# Out:
# State        10287
# Country      33782
# Lat          33782
# Long         33782
# Date         33782
# Confirmed    33782
# Death        33274
# Recovered    30226
# dtype: int64

# %%
# Imputing Missing Values- State
# Let's check one value
combined_df.set_index('Country').filter(like='India',axis=0)
# Out:
#         State   Lat  Long       Date  Confirmed   Death  Recovered
# Country
# India     NaN  21.0  78.0 2020-01-22          0     0.0        0.0
# India     NaN  21.0  78.0 2020-01-23          0     0.0        0.0
# India     NaN  21.0  78.0 2020-01-24          0     0.0        0.0
# India     NaN  21.0  78.0 2020-01-25          0     0.0        0.0
# India     NaN  21.0  78.0 2020-01-26          0     0.0        0.0
# ...       ...   ...   ...        ...        ...     ...        ...
# India     NaN  21.0  78.0 2020-05-23     131423  3868.0    54385.0
# India     NaN  21.0  78.0 2020-05-24     138536  4024.0    57692.0
# India     NaN  21.0  78.0 2020-05-25     144950  4172.0    60706.0
# India     NaN  21.0  78.0 2020-05-26     150793  4344.0    64277.0
# India     NaN  21.0  78.0 2020-05-27     158086  4534.0    67749.0
#
# [127 rows x 7 columns]

# %%
# We cans see here that India country has State column as null and Lat, Long is ame along all rows.

# %%
# Take the count of all COuntries where valjues are null
combined_df[combined_df.State.isnull()]['Country'].value_counts()
# Out:
# Angola                 127
# Italy                  127
# Bolivia                127
# Belgium                127
# Tanzania               127
#                       ...
# Netherlands            127
# Timor-Leste            127
# Trinidad and Tobago    127
# Rwanda                 127
# Barbados               127
# Name: Country, Length: 185, dtype: int64

# %%
# We can see here that total 185 countries are there, which has null columns. Now, let's try imputing State with Lat and Long. FOr that, will sue GoogleMaps

# %%
# !pip install -U googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.4.1-cp36-none-any.whl size=37819 sha256=7625830caa8c662bc1edb6ebc71309637cdf4713f017c11ae3d5080d51ebc71a
#   Stored in directory: /root/.cache/pip/wheels/5c/ec/b9/9d0c26b80d7dcf16496c82e8108c93186c6d4df097a41bba4f
# Successfully built googlemaps
# ...

# %%
import googlemaps

# %%
gmaps = googlemaps.Client(key= config.get('twitter','googleapikey'))
geocode_result = gmaps.reverse_geocode((-23.4425, -58.4438))
print(geocode_result[0])
print(geocode_result[0]['formatted_address'])
print(geocode_result[0]['formatted_address'].split(",")[-2].strip(""))
# Out:
# {'access_points': [], 'address_components': [{'long_name': 'Pozo Colorado', 'short_name': 'Pozo Colorado', 'types': ['neighborhood', 'political']}, {'long_name': 'Villa Hayes', 'short_name': 'Villa Hayes', 'types': ['locality', 'political']}, {'long_name': 'Villa Hayes', 'short_name': 'Villa Hayes', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Presidente Hayes', 'short_name': 'Presidente Hayes', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Paraguay', 'short_name': 'PY', 'types': ['country', 'political']}], 'formatted_address': 'Pozo Colorado, Villa Hayes, Paraguay', 'geometry': {'bounds': {'northeast': {'lat': -23.2437722, 'lng': -58.1943502}, 'southwest': {'lat': -23.5721188, 'lng': -59.4172115}}, 'location': {'lat': -23.4165497, 'lng': -58.7237247}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -23.2437722, 'lng': -58.1943502}, 'southwest': {'lat': -23.5721188, 'lng': -59.4172115}}}, 'place_id': 'ChIJkz1C4V8-b5
# ...

# %%
import re

english_check = re.compile(r'[a-z]')

def get_state(lat,long):
  try:
    output = gmaps.reverse_geocode((lat,long))[0]['formatted_address'].split(",")[-2].strip()
    # in some countries such as- in India, if we don';t split like this tyhen it is taking country name with geocode, which we don't want
    if(len(output.split(" "))>1):
      output="TBF"
    if not english_check.match(output.lower()):
      output="TBF"
  except:
    print("Error in Reverse Geoencoding")
    output="TBF"
  return output

# %%
combined_df["state_cleaned"]= combined_df[combined_df.State.isnull()][['Lat','Long']].apply(lambda x: get_state(x['Lat'], x['Long']), axis=1)
# Out:
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# Error in Reverse Geoencoding
# ...

# %%
#error in reverse geoencoding means it is not getting the appropriate latitude and Longitude values

# %%
# check for null values again in the new column generated- state_cleaned
combined_df[combined_df.state_cleaned.isnull()]['Country'].value_counts()
# Out:
# China             4191
# Canada            1778
# France            1270
# United Kingdom    1270
# Australia         1016
# Netherlands        508
# Denmark            254
# Name: Country, dtype: int64

# %%
combined_int_df = combined_df.copy()

# %%
combined_df[combined_df.state_cleaned.notna()]
# Out:
#       State                Country        Lat  ...  Death Recovered  state_cleaned
# 0       NaN            Afghanistan  33.000000  ...    0.0       0.0        Baghran
# 1       NaN                Albania  41.153300  ...    0.0       0.0           E852
# 2       NaN                Algeria  28.033900  ...    0.0       0.0       Timokten
# 3       NaN                Andorra  42.506300  ...    0.0       0.0            TBF
# 4       NaN                 Angola -11.202700  ...    0.0       0.0            TBF
# ...     ...                    ...        ...  ...    ...       ...            ...
# 33777   NaN  Sao Tome and Principe   0.186360  ...   12.0      68.0             st
# 33778   NaN                  Yemen  15.552727  ...   53.0       NaN            TBF
# 33779   NaN                Comoros -11.645500  ...    2.0      24.0        Oichili
# 33780   NaN             Tajikistan  38.861034  ...   47.0       NaN      Tavildara
# ...

# %%
combined_int_df[combined_df.State.notna()]
# Out:
#                                   State  ... state_cleaned
# 8          Australian Capital Territory  ...           NaN
# 9                       New South Wales  ...           NaN
# 10                   Northern Territory  ...           NaN
# 11                           Queensland  ...           NaN
# 12                      South Australia  ...           NaN
# ...                                 ...  ...           ...
# 33765            British Virgin Islands  ...           NaN
# 33766          Turks and Caicos Islands  ...           NaN
# 33771  Bonaire, Sint Eustatius and Saba  ...           NaN
# 33773       Falkland Islands (Malvinas)  ...           NaN
# 33774         Saint Pierre and Miquelon  ...           NaN
#
# [10287 rows x 9 columns]

# %%
# here, it can be seen that State column is not null, but, state_Cleaned is null. Since, we did not impute values when state is not null for state_cleaned column.
# Thus, will have to merge State and State_cleaned column

# %%
combined_int_df[combined_df.State.notna()]['State'].count()
# Out:
# 10287

# %%
# now, merge state and state_cleaned column together
combined_int_df["state_cleaned"] = combined_int_df.apply(lambda x: x['State'] if (np.all(pd.notnull(x['State']))) else x['state_cleaned'], axis=1 )

# %%
combined_int_df[combined_df.State.notna()]
# Out:
#                                   State  ...                     state_cleaned
# 8          Australian Capital Territory  ...      Australian Capital Territory
# 9                       New South Wales  ...                   New South Wales
# 10                   Northern Territory  ...                Northern Territory
# 11                           Queensland  ...                        Queensland
# 12                      South Australia  ...                   South Australia
# ...                                 ...  ...                               ...
# 33765            British Virgin Islands  ...            British Virgin Islands
# 33766          Turks and Caicos Islands  ...          Turks and Caicos Islands
# 33771  Bonaire, Sint Eustatius and Saba  ...  Bonaire, Sint Eustatius and Saba
# 33773       Falkland Islands (Malvinas)  ...       Falkland Islands (Malvinas)
# 33774         Saint Pierre and Miquelon  ...         Saint Pierre and Miquelon
#
# ...

# %%
combined_int_df[combined_df.state_cleaned=="TBF"]
# Out:
#       State                Country        Lat  ...  Death Recovered  state_cleaned
# 3       NaN                Andorra  42.506300  ...    0.0       0.0            TBF
# 4       NaN                 Angola -11.202700  ...    0.0       0.0            TBF
# 5       NaN    Antigua and Barbuda  17.060800  ...    0.0       0.0            TBF
# 6       NaN              Argentina -38.416100  ...    0.0       0.0            TBF
# 7       NaN                Armenia  40.069100  ...    0.0       0.0            TBF
# ...     ...                    ...        ...  ...    ...       ...            ...
# 33759   NaN  Saint Kitts and Nevis  17.357822  ...    0.0      15.0            TBF
# 33762   NaN                 Kosovo  42.602636  ...   30.0     794.0            TBF
# 33767   NaN             MS Zaandam   0.000000  ...    2.0       0.0            TBF
# 33776   NaN         Western Sahara  24.215500  ...    1.0       6.0            TBF
# ...

# %%
combined_int_df[combined_df.state_cleaned=="TBF"]["Country"].value_counts()
#TBF is to be filled
# Out:
# Estonia                127
# Cabo Verde             127
# Paraguay               127
# Rwanda                 127
# Trinidad and Tobago    127
#                       ...
# Bolivia                127
# MS Zaandam             127
# Papua New Guinea       127
# Andorra                127
# Barbados               127
# Name: Country, Length: 107, dtype: int64

# %%
combined_int_df.head(20)
# Out:
#                            State  ...                 state_cleaned
# 0                            NaN  ...                       Baghran
# 1                            NaN  ...                          E852
# 2                            NaN  ...                      Timokten
# 3                            NaN  ...                           TBF
# 4                            NaN  ...                           TBF
# 5                            NaN  ...                           TBF
# 6                            NaN  ...                           TBF
# 7                            NaN  ...                           TBF
# 8   Australian Capital Territory  ...  Australian Capital Territory
# 9                New South Wales  ...               New South Wales
# 10            Northern Territory  ...            Northern Territory
# 11                    Queensland  ...                    Queensland
# 12               South Australia  ...               South Australia
# ...

# %%
# Retrieve country and Capital List from another dataframe
capital_df = pd.read_csv('https://raw.githubusercontent.com/icyrockcom/country-capitals/master/data/country-list.csv')
capital_df
# Out:
#                    country              capital            type
# 0                 Abkhazia              Sukhumi  countryCapital
# 1              Afghanistan                Kabul  countryCapital
# 2    Akrotiri and Dhekelia  Episkopi Cantonment  countryCapital
# 3                  Albania               Tirana  countryCapital
# 4                  Algeria              Algiers  countryCapital
# ..                     ...                  ...             ...
# 243      Wallis and Futuna             Mata-Utu  countryCapital
# 244         Western Sahara             El Aaiún  countryCapital
# 245                  Yemen                Sanaá  countryCapital
# 246                 Zambia               Lusaka  countryCapital
# 247               Zimbabwe               Harare  countryCapital
#
# [248 rows x 3 columns]

# %%
capital_df.country.replace({'"United Kingdom; England"':'United Kingdom'}, inplace=True)

# %%
capital_df.country = capital_df.country.str.lower()

# %%
capital_df.head()
# Out:
#                  country              capital            type
# 0               abkhazia              Sukhumi  countryCapital
# 1            afghanistan                Kabul  countryCapital
# 2  akrotiri and dhekelia  Episkopi Cantonment  countryCapital
# 3                albania               Tirana  countryCapital
# 4                algeria              Algiers  countryCapital

# %%
# make country as index
capital_df.set_index('country', inplace=True)

# %%
capital_df.head()
# Out:
#                                    capital            type
# country
# abkhazia                           Sukhumi  countryCapital
# afghanistan                          Kabul  countryCapital
# akrotiri and dhekelia  Episkopi Cantonment  countryCapital
# albania                             Tirana  countryCapital
# algeria                            Algiers  countryCapital

# %%
capital_df.loc['algeria'][0]
# Out:
# 'Algiers'

# %%
# will replace TBF values with capital for countries, if exists
combined_int_df[combined_int_df.state_cleaned=="TBF"]
# Out:
#       State                Country        Lat  ...  Death Recovered  state_cleaned
# 3       NaN                Andorra  42.506300  ...    0.0       0.0            TBF
# 4       NaN                 Angola -11.202700  ...    0.0       0.0            TBF
# 5       NaN    Antigua and Barbuda  17.060800  ...    0.0       0.0            TBF
# 6       NaN              Argentina -38.416100  ...    0.0       0.0            TBF
# 7       NaN                Armenia  40.069100  ...    0.0       0.0            TBF
# ...     ...                    ...        ...  ...    ...       ...            ...
# 33759   NaN  Saint Kitts and Nevis  17.357822  ...    0.0      15.0            TBF
# 33762   NaN                 Kosovo  42.602636  ...   30.0     794.0            TBF
# 33767   NaN             MS Zaandam   0.000000  ...    2.0       0.0            TBF
# 33776   NaN         Western Sahara  24.215500  ...    1.0       6.0            TBF
# ...

# %%
# will replace TBF values with capital for countries, if exists
def lookup_capital(country):
  try:
    capital = capital_df.loc[country.lower()][0]
  except:
    capital = "TBF"
  return capital

# %%
combined_int_df.state_cleaned=combined_int_df.apply(lambda x: lookup_capital(x['Country']) if (x['state_cleaned']=="TBF") else x["state_cleaned"], axis=1)

# %%
combined_int_df[combined_int_df.state_cleaned=="TBF"]["Country"].value_counts()
# Out:
# Holy See              127
# United Kingdom        127
# Cabo Verde            127
# Diamond Princess      127
# MS Zaandam            127
# Cote d'Ivoire         127
# Bolivia               127
# Eswatini              127
# US                    127
# Czechia               127
# West Bank and Gaza    127
# Name: Country, dtype: int64

# %%
combined_int_df.loc[33739].Country
# Out:
# 'United Kingdom'

# %%
#Do some data Cleaning
combined_int_df["Country"].replace({"Holy See":"Vatican City", "US": "United States","Cabo Verde":"Cape Verde","MS Zaandam":"Netherlands", "US":"United States",
                                    "Czechia":"Czech Republic","West Bank and Gaza":"Israel"},inplace=True)

# %%
combined_int_df[combined_int_df.state_cleaned=="TBF"]["Country"].value_counts()
# Out:
# United States       127
# United Kingdom      127
# Diamond Princess    127
# Cote d'Ivoire       127
# Bolivia             127
# Eswatini            127
# Vatican City        127
# Israel              127
# Netherlands         127
# Cape Verde          127
# Czech Republic      127
# Name: Country, dtype: int64

# %%
combined_int_df.state_cleaned=combined_int_df.apply(lambda x: lookup_capital(x['Country']) if (x['state_cleaned']=="TBF") else x["state_cleaned"], axis=1)

# %%
combined_int_df[combined_int_df.state_cleaned=="TBF"]["Country"].value_counts()
# Out:
# Diamond Princess    127
# Eswatini            127
# Cote d'Ivoire       127
# Bolivia             127
# United Kingdom      127
# Name: Country, dtype: int64

# %%
#Only 5 countries are left with empty values
#Now, just copy country name to places where state_cleaned="TBF"
combined_int_df.state_cleaned=combined_int_df.apply(lambda x: x['Country'] if (x['state_cleaned']=="TBF") else x["state_cleaned"], axis=1)

# %%
combined_int_df[combined_int_df.Country == "United States"]
# Out:
#       State        Country      Lat  ...     Death Recovered     state_cleaned
# 225     NaN  United States  37.0902  ...       0.0       0.0  Washington, D.C.
# 491     NaN  United States  37.0902  ...       0.0       0.0  Washington, D.C.
# 757     NaN  United States  37.0902  ...       0.0       0.0  Washington, D.C.
# 1023    NaN  United States  37.0902  ...       0.0       0.0  Washington, D.C.
# 1289    NaN  United States  37.0902  ...       0.0       0.0  Washington, D.C.
# ...     ...            ...      ...  ...       ...       ...               ...
# 32677   NaN  United States  37.0902  ...   97086.0  361239.0  Washington, D.C.
# 32943   NaN  United States  37.0902  ...   97719.0  366736.0  Washington, D.C.
# 33209   NaN  United States  37.0902  ...   98219.0  379157.0  Washington, D.C.
# 33475   NaN  United States  37.0902  ...   98912.0  384902.0  Washington, D.C.
# 33741   NaN  United States  37.0902  ...  100417.0  391508.0  Washington, D.C.
#
# [127 rows x 9 columns]

# %%
combined_int_df.to_csv("corona_dataset.csv")
